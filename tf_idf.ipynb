# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd
from preprocess_speech import preprocess_speech
from scipy.sparse.linalg import svds

# %%
# Load only the first 1000 lines of the data.csv file with the speeches
df = pd.read_csv('processed_data.csv', nrows=1000)

df.head(-1)
# Out:
#                               member_name sitting_date  \
# 0                αργυρης ιωαννη ευαγγελος   10/01/2012
# 1                αργυρης ιωαννη ευαγγελος   10/01/2012
# 2          σαλαγιαννης βασιλειου νικολαος   10/01/2012
# 3                αργυρης ιωαννη ευαγγελος   10/01/2012
# 4                βλαχος θεοδωρου γεωργιος   10/01/2012
# ..                                    ...          ...
# 994            δριτσας παναγιωτη θεοδωρος   16/01/2012
# 995  νικολαιδου αρισταρχου βαρβαρα (βερα)   16/01/2012
# 996           σηφουνακης οδυσσεα νικολαος   16/01/2012
# 997            δριτσας παναγιωτη θεοδωρος   16/01/2012
# 998  νικολαιδου αρισταρχου βαρβαρα (βερα)   16/01/2012
#
#                          political_party  \
# 0         πανελληνιο σοσιαλιστικο κινημα
# 1         πανελληνιο σοσιαλιστικο κινημα
# 2         πανελληνιο σοσιαλιστικο κινημα
# 3         πανελληνιο σοσιαλιστικο κινημα
# 4                         νεα δημοκρατια
# ..                                   ...
# 994  συνασπισμος ριζοσπαστικης αριστερας
# 995          κομμουνιστικο κομμα ελλαδας
# 996       πανελληνιο σοσιαλιστικο κινημα
# 997  συνασπισμος ριζοσπαστικης αριστερας
# 998          κομμουνιστικο κομμα ελλαδας
#
#                                                 speech      id
# 0    κυρι συναδελφ ηθελ αρχ ευχ καλ χρον υγει δημιο...  841327
# 1    κυρι συναδελφ εισερχ ημερησ διαταξ τησνομοθετι...  841329
# 2    προεδρ κυρι συναδελφ αρχ ηθελ σειρ δωσ εγκαρδι...  841330
# 3    ευχαριστ σαλαγιαννη κοινοβουλευτικ εκπροσωπ κο...  841331
# 4    ευχαριστ προεδρ ευχ χρον καλ χρονιακυρι συναδε...  841332
# ..                                                 ...     ...
# 994                                    προβοκατσ απαντ  842408
# 995                          υπουργ περιοριστ θεμ χρον  842409
# 996  απειλ βουλ εισαστ διν μαθημ δημοκρατι μπορ τρο...  842410
# 997                      απαντατ εμ απαντ κοινωνικ φορ  842411
# 998                       υπουργ εκτ θεμ περιοριστ θεμ  842412
#
# [999 rows x 5 columns]

# %%
# Create a TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(df['speech'])

# Fit the vectorizer to the speeches
X = vectorizer.transform(df['speech'])

print("Size of TF-IDF matrix: ", X.shape)
print("Sparsity of the TF_IDF matrix: ", 1 - X.size / (X.shape[0] * X.shape[1]))
# Out:
# Size of TF-IDF matrix:  (1000, 9172)
# Sparsity of the TF_IDF matrix:  0.9941846925425207

# %%
df.head(-1)
# Out:
#                               member_name sitting_date  \
# 0                αργυρης ιωαννη ευαγγελος   10/01/2012
# 1                αργυρης ιωαννη ευαγγελος   10/01/2012
# 2          σαλαγιαννης βασιλειου νικολαος   10/01/2012
# 3                αργυρης ιωαννη ευαγγελος   10/01/2012
# 4                βλαχος θεοδωρου γεωργιος   10/01/2012
# ..                                    ...          ...
# 994            δριτσας παναγιωτη θεοδωρος   16/01/2012
# 995  νικολαιδου αρισταρχου βαρβαρα (βερα)   16/01/2012
# 996           σηφουνακης οδυσσεα νικολαος   16/01/2012
# 997            δριτσας παναγιωτη θεοδωρος   16/01/2012
# 998  νικολαιδου αρισταρχου βαρβαρα (βερα)   16/01/2012
#
#                          political_party  \
# 0         πανελληνιο σοσιαλιστικο κινημα
# 1         πανελληνιο σοσιαλιστικο κινημα
# 2         πανελληνιο σοσιαλιστικο κινημα
# 3         πανελληνιο σοσιαλιστικο κινημα
# 4                         νεα δημοκρατια
# ..                                   ...
# 994  συνασπισμος ριζοσπαστικης αριστερας
# 995          κομμουνιστικο κομμα ελλαδας
# 996       πανελληνιο σοσιαλιστικο κινημα
# 997  συνασπισμος ριζοσπαστικης αριστερας
# 998          κομμουνιστικο κομμα ελλαδας
#
#                                                 speech      id
# 0    κυρι συναδελφ ηθελ αρχ ευχ καλ χρον υγει δημιο...  841327
# 1    κυρι συναδελφ εισερχ ημερησ διαταξ τησνομοθετι...  841329
# 2    προεδρ κυρι συναδελφ αρχ ηθελ σειρ δωσ εγκαρδι...  841330
# 3    ευχαριστ σαλαγιαννη κοινοβουλευτικ εκπροσωπ κο...  841331
# 4    ευχαριστ προεδρ ευχ χρον καλ χρονιακυρι συναδε...  841332
# ..                                                 ...     ...
# 994                                    προβοκατσ απαντ  842408
# 995                          υπουργ περιοριστ θεμ χρον  842409
# 996  απειλ βουλ εισαστ διν μαθημ δημοκρατι μπορ τρο...  842410
# 997                      απαντατ εμ απαντ κοινωνικ φορ  842411
# 998                       υπουργ εκτ θεμ περιοριστ θεμ  842412
#
# [999 rows x 5 columns]

# %%
U, S, V = svds(X, k=200)   
X_app = np.linalg.multi_dot([U, np.diag(S)])  # Approximation of speeches in k dimensions

# %%
print(U.shape, S.shape, V.shape)
print(S)
# Out:
# (1000, 200) (200,) (200, 9172)
# [1.07969206 1.08112056 1.08232884 1.08426638 1.08569421 1.08809588
#  1.09073707 1.09122076 1.09263383 1.09355449 1.09675693 1.09927395
#  1.10277424 1.10533033 1.10679259 1.10816557 1.10990746 1.11113518
#  1.11743776 1.11923075 1.12050439 1.12141821 1.12647934 1.12764163
#  1.12886157 1.13141648 1.13530614 1.13709706 1.13956774 1.14044006
#  1.14130528 1.14271103 1.14437995 1.14957501 1.15203217 1.15241359
#  1.15631023 1.15983481 1.16220482 1.16395397 1.16786347 1.16933572
#  1.17199293 1.1750655  1.17661991 1.17895332 1.18340954 1.18424811
#  1.18515629 1.19001248 1.19230941 1.19486531 1.19787799 1.19981361
#  1.20232949 1.20522433 1.20901412 1.21205249 1.21677545 1.21893725
#  1.22206397 1.22526505 1.2270631  1.22846014 1.23219059 1.23309945
#  1.23715931 1.24418427 1.24612572 1.24746084 1.25039581 1.25277115
#  1.26009189 1.26194626 1.26392021 1.26596662 1.27264988 1.27462077
#  1.27760051 1.28041262 1.28312797 1.28568901 1.28729936 1.28980526
#  1.29220178 1.29586625 1.29959852 1.30519582 1.3055314  1.31151044
#  1.31498354 1.31650576 1.31883874 1.32501953 1.32628332 1.33015965
#  1.33262571 1.34075552 1.34266922 1.34434676 1.34805272 1.3500069
#  1.35578854 1.3604539  1.36430285 1.36882041 1.37321639 1.37423235
#  1.38418279 1.38928563 1.39519431 1.39700754 1.40023087 1.40441365
#  1.41174343 1.41788146 1.42192512 1.42486208 1.43436477 1.43828122
#  1.4430332  1.44806839 1.46299303 1.46449902 1.47608243 1.48276909
#  1.48471135 1.48804971 1.49952713 1.50859075 1.5115744  1.51816468
#  1.52229777 1.5378582  1.54230182 1.55447094 1.56105044 1.57044417
#  1.58230837 1.58455473 1.59331074 1.6063423  1.60774377 1.61775319
#  1.62370079 1.63619012 1.63959788 1.64505004 1.66167317 1.66954715
#  1.67780231 1.68711323 1.69493455 1.70478271 1.71117586 1.72691286
#  1.74374373 1.74613315 1.75359449 1.76219159 1.76894452 1.78948046
#  1.80479756 1.82174592 1.83869255 1.86577744 1.8717134  1.89392806
#  1.89714795 1.93699639 1.94201521 1.97355752 1.98775551 2.02394572
#  2.05429828 2.07794516 2.08708591 2.13816187 2.16448114 2.19323541
#  2.2429615  2.2554213  2.27684554 2.31561628 2.36701825 2.45818617
#  2.52382879 2.63619632 2.71489265 2.78684555 2.83784997 3.02207775
#  3.26278644 3.68113634 3.90784977 3.99185952 4.30508066 5.45209247
#  7.20645484 9.85169908]

# %%
# Μπορώ οποιαδήποτε ομιλία να χρησιμοποιησω τον ετοιμο vectorizer και να τη φερω στις 200 διαστασεις πολλαπλασιάζοντας με V transposed - ΤΕΣΤ (ΕΠΙΤΥΧΕΣ)
test_speech = "Καλησπέρα σας. Είμαι ο Γιώργος"
test_speech = preprocess_speech(test_speech)
test_speech_vector = vectorizer.transform([test_speech])
print(test_speech_vector.shape)
test_speech_vector = np.dot(test_speech_vector.toarray(), V.T)
print(test_speech_vector.shape)
# Out:
# (1, 9172)
# (1, 200)

# %%
X_app.shape
# Out:
# (1000, 200)
